# %%
pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in c:\users\dell\appdata\roaming\python\python313\site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.24.1 in c:\users\dell\appdata\roaming\python\python313\site-packages (from scikit-learn) (2.3.5)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\dell\appdata\roaming\python\python313\site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\dell\appdata\roaming\python\python313\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\dell\appdata\roaming\python\python313\site-packages (from scikit-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd

df=pd.read_csv('../data/raw/customers.csv')

# %%
# Separate target
y = df['Churn']

# Drop non-feature columns
X = df.drop(['Churn', 'customerID'], axis=1)

# %%
y = y.map({'Yes':1, 'No':0})

# %%
cat_cols = X.select_dtypes(include='object').columns
num_cols = X.select_dtypes(exclude='object').columns

print(cat_cols)
print(num_cols)
# Out:
# Index(['gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'TotalCharges'],
#       dtype='object')
# Index(['SeniorCitizen', 'tenure', 'MonthlyCharges'], dtype='object')

# %%
X_encoded = pd.get_dummies(X, columns=cat_cols, drop_first=True)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_encoded[num_cols] = scaler.fit_transform(X_encoded[num_cols])

# %%
import numpy as np

X_final = np.array(X_encoded)
y_final = np.array(y)

# %% [markdown]
# TESTING:

# %%
print(X_final.shape)
print(y_final.shape)
# Out:
# (7043, 6559)
# (7043,)
